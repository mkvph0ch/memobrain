# %% [markdown]
# # Scaling and Encoding OASIS 1

# %% [markdown]
# ##  Imports

# %%
# DATA MANIPULATION
import pandas as pd
import numpy as np

# DATA VISUALISATION
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# MACHINE LEARNING
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ###  Dataset

# %%
oasis1_cs_path = '../raw_data/OASIS1/oasis_cross-sectional.csv'

# %%
oasis1 = pd.read_csv(oasis1_cs_path)

# %% [markdown]
# Note to self:
#
#
# **CDR;** 0= nondemented; 0.5 – very mild dementia; 1 = mild dementia; 2 = moderate dementia
#
# **eTIV;** Estimated total intracranial volume (eTIV)
#
# **nWBV** Normalized whole brain volume
#
# **ASF;** Atlas scaling factor

# %%
oasis1.sample(20)
# Out:
#                 ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 249  OAS1_0277_MR1   M    R   22   NaN  NaN   NaN  NaN  1913  0.841  0.917
# 105  OAS1_0113_MR1   F    R   83   2.0  2.0  29.0  0.0  1569  0.768  1.118
# 297  OAS1_0329_MR1   F    R   80   2.0  3.0  29.0  0.5  1209  0.760  1.451
# 206  OAS1_0227_MR1   F    R   26   NaN  NaN   NaN  NaN  1288  0.777  1.362
# 153  OAS1_0165_MR1   F    R   74   2.0  3.0  29.0  0.0  1395  0.787  1.258
# 240  OAS1_0267_MR1   M    R   80   5.0  2.0  28.0  0.5  1506  0.679  1.166
# 314  OAS1_0348_MR1   F    R   22   NaN  NaN   NaN  NaN  1473  0.841  1.191
# 302  OAS1_0335_MR1   F    R   80   1.0  4.0  27.0  0.5  1654  0.678  1.061
# 331  OAS1_0367_MR1   F    R   46   2.0  2.0  28.0  0.0  1161  0.841  1.511
# 404  OAS1_0446_MR1   F    R   80   2.0  4.0  30.0  0.0  1390  0.748  1.263
# 7    OAS1_0009_MR1   F    R   20   NaN  NaN   NaN  NaN  1505  0.843  1.166
# 89   OAS1_0096_MR1   F    R   47   5.0  2.0  29.0  0.0  1357  0.809  1.294
# 379  OAS1_0419_MR1   F    R   21   NaN  NaN   NaN  NaN  1473  0.862  1.191
# 399  OAS1_0441_MR1   M    R   81   5.0  1.0  29.0  0.5  1647  0.721  1.066
# 405  OAS1_0447_MR1   F    R   92   4.0  1.0  24.0  0.5  1388  0.739  1.264
# 205  OAS1_0226_MR1   M    R   90   1.0  4.0  23.0  0.5  1668  0.644  1.052
# 369  OAS1_0407_MR1   F    R   55   NaN  NaN   NaN  NaN  1434  0.807  1.224
# 58   OAS1_0063_MR1   M    R   48   NaN  NaN   NaN  NaN  1675  0.818  1.048
# 37   OAS1_0041_MR1   F    R   62   2.0  NaN  28.0  0.5  1350  0.758  1.300
# 2    OAS1_0003_MR1   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
#
#      Delay
# 249    NaN
# 105    NaN
# 297    NaN
# 206    NaN
# 153    NaN
# 240    NaN
# 314    NaN
# 302    NaN
# 331    NaN
# 404    NaN
# 7      NaN
# 89     NaN
# 379    NaN
# 399    NaN
# 405    NaN
# 205    NaN
# 369    NaN
# 58     NaN
# 37     NaN
# 2      NaN

# %% [markdown]
# ## Scaling Numerical Features

# %% [markdown]
#  Note: nWBV already normalized
#
# **Columns to scale:**
#
# Standard Scale: age, ASF
#
# Robust Scale: eTIV

# %%
# Instantiating scalers

standard_scaler = StandardScaler()
robust_scaler = RobustScaler()

# %%
features_standard = ["Age"]
features_robust = ["eTIV", "MMSE"]

# %%
# Creating a copy of the original dataset
oasis1_scaled = oasis1.copy()

# %%
oasis1_scaled[features_standard] = standard_scaler.fit_transform(oasis1_scaled[features_standard])
oasis1_scaled
# Out:
#                 ID M/F Hand       Age  Educ  SES  MMSE  CDR  eTIV   nWBV  \
# 0    OAS1_0001_MR1   F    R  0.897045   2.0  3.0  29.0  0.0  1344  0.743
# 1    OAS1_0002_MR1   F    R  0.144298   4.0  1.0  29.0  0.0  1147  0.810
# 2    OAS1_0003_MR1   F    R  0.857427   4.0  3.0  27.0  0.5  1454  0.708
# 3    OAS1_0004_MR1   M    R -0.925396   NaN  NaN   NaN  NaN  1588  0.803
# 4    OAS1_0005_MR1   M    R -1.321579   NaN  NaN   NaN  NaN  1737  0.848
# ..             ...  ..  ...       ...   ...  ...   ...  ...   ...    ...
# 431  OAS1_0285_MR2   M    R -1.242342   NaN  NaN   NaN  NaN  1469  0.847
# 432  OAS1_0353_MR2   M    R -1.163106   NaN  NaN   NaN  NaN  1684  0.790
# 433  OAS1_0368_MR2   M    R -1.163106   NaN  NaN   NaN  NaN  1580  0.856
# 434  OAS1_0379_MR2   F    R -1.242342   NaN  NaN   NaN  NaN  1262  0.861
# 435  OAS1_0395_MR2   F    R -1.004633   NaN  NaN   NaN  NaN  1283  0.834
#
#        ASF  Delay
# 0    1.306    NaN
# 1    1.531    NaN
# 2    1.207    NaN
# 3    1.105    NaN
# 4    1.010    NaN
# ..     ...    ...
# 431  1.195    2.0
# 432  1.042   40.0
# 433  1.111   89.0
# 434  1.390    2.0
# 435  1.368   39.0
#
# [436 rows x 12 columns]

# %%
oasis1_scaled[features_robust] = standard_scaler.fit_transform(oasis1_scaled[features_robust])

# %% [markdown]
# ## Scaling Categorical Features

# %%
# This code is precautionary and drops NAN in CDR columns. However, all NAN are supposed to have been dropped already.
oasis1.dropna(subset = ["CDR"], inplace=True)
oasis1_scaled.dropna(subset = ["CDR"], inplace=True)

# %%
ohe = OneHotEncoder(drop='if_binary', sparse = False)

ohe.fit(oasis1[['CDR']])

oasis1_scaled['nondemented'], oasis1_scaled['very_mild_dementia'], oasis1_scaled['mild_dementia'], oasis1_scaled['moderate_dementia'] = ohe.transform(oasis1_scaled[['CDR']]).T

# %%
oasis1.CDR.unique()
# Out:
# array([0. , 0.5, 1. , 2. ])

# %% [markdown]
# ## Transforming other features

# %%
# Female: 0
# Male: 1
oasis1_scaled['M/F'].replace('F', 0,inplace=True)
oasis1_scaled['M/F'].replace('M', 1,inplace=True)

# %%
oasis1_scaled
# Out:
#                 ID  M/F Hand       Age  Educ  SES      MMSE  CDR      eTIV  \
# 0    OAS1_0001_MR1    0    R  0.897045   2.0  3.0  0.524850  0.0 -0.869834
# 1    OAS1_0002_MR1    0    R  0.144298   4.0  1.0  0.524850  0.0 -2.112276
# 2    OAS1_0003_MR1    0    R  0.857427   4.0  3.0 -0.017303  0.5 -0.176084
# 8    OAS1_0010_MR1    1    R  0.897045   5.0  2.0  0.795927  0.0  0.971755
# 9    OAS1_0011_MR1    0    R  0.025443   3.0  2.0  0.795927  0.0 -1.014890
# ..             ...  ...  ...       ...   ...  ...       ...  ...       ...
# 411  OAS1_0453_MR1    0    R  0.738572   1.0  4.0  0.524850  0.5 -1.178868
# 412  OAS1_0454_MR1    0    R  0.857427   3.0  2.0 -1.101609  0.5  0.341074
# 413  OAS1_0455_MR1    0    R  0.382008   2.0  4.0  0.253774  0.0 -0.806766
# 414  OAS1_0456_MR1    1    R  0.382008   5.0  2.0  0.795927  0.0  0.978062
# 415  OAS1_0457_MR1    0    R  0.421626   3.0  3.0 -0.288379  0.0 -0.693243
#
#       nWBV    ASF  Delay  nondemented  very_mild_dementia  mild_dementia  \
# 0    0.743  1.306    NaN          1.0                 0.0            0.0
# 1    0.810  1.531    NaN          1.0                 0.0            0.0
# 2    0.708  1.207    NaN          0.0                 1.0            0.0
# 8    0.689  1.073    NaN          1.0                 0.0            0.0
# 9    0.827  1.329    NaN          1.0                 0.0            0.0
# ..     ...    ...    ...          ...                 ...            ...
# 411  0.748  1.355    NaN          0.0                 1.0            0.0
# 412  0.730  1.142    NaN          0.0                 1.0            0.0
# 413  0.825  1.297    NaN          1.0                 0.0            0.0
# 414  0.780  1.072    NaN          1.0                 0.0            0.0
# 415  0.766  1.279    NaN          1.0                 0.0            0.0
#
#      moderate_dementia
# 0                  0.0
# 1                  0.0
# 2                  0.0
# 8                  0.0
# 9                  0.0
# ..                 ...
# 411                0.0
# 412                0.0
# 413                0.0
# 414                0.0
# 415                0.0
#
# [235 rows x 16 columns]

# %%
oasis1_scaled.SES.value_counts()
# Out:
# 2.0    65
# 1.0    50
# 3.0    49
# 4.0    49
# 5.0     3
# Name: SES, dtype: int64
