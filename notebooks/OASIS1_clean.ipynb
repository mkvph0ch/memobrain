# %%
import pandas as pd

data = pd.read_csv("oasis_cross-sectional.csv")

data.head(20)
# Out:
#                ID M/F Hand  Age  Educ  SES  MMSE  CDR  eTIV   nWBV    ASF  \
# 0   OAS1_0001_MR1   F    R   74   2.0  3.0  29.0  0.0  1344  0.743  1.306
# 1   OAS1_0002_MR1   F    R   55   4.0  1.0  29.0  0.0  1147  0.810  1.531
# 2   OAS1_0003_MR1   F    R   73   4.0  3.0  27.0  0.5  1454  0.708  1.207
# 3   OAS1_0004_MR1   M    R   28   NaN  NaN   NaN  NaN  1588  0.803  1.105
# 4   OAS1_0005_MR1   M    R   18   NaN  NaN   NaN  NaN  1737  0.848  1.010
# 5   OAS1_0006_MR1   F    R   24   NaN  NaN   NaN  NaN  1131  0.862  1.551
# 6   OAS1_0007_MR1   M    R   21   NaN  NaN   NaN  NaN  1516  0.830  1.157
# 7   OAS1_0009_MR1   F    R   20   NaN  NaN   NaN  NaN  1505  0.843  1.166
# 8   OAS1_0010_MR1   M    R   74   5.0  2.0  30.0  0.0  1636  0.689  1.073
# 9   OAS1_0011_MR1   F    R   52   3.0  2.0  30.0  0.0  1321  0.827  1.329
# 10  OAS1_0012_MR1   M    R   30   NaN  NaN   NaN  NaN  1574  0.842  1.115
# 11  OAS1_0013_MR1   F    R   81   5.0  2.0  30.0  0.0  1664  0.679  1.055
# ...

# %%
data.index = data.index + 1

# %%
patients_to_remove = data[data['CDR'].isnull()].ID.tolist()
patients_to_remove
# Out:
# ['OAS1_0004_MR1',
#  'OAS1_0005_MR1',
#  'OAS1_0006_MR1',
#  'OAS1_0007_MR1',
#  'OAS1_0009_MR1',
#  'OAS1_0012_MR1',
#  'OAS1_0014_MR1',
#  'OAS1_0017_MR1',
#  'OAS1_0025_MR1',
#  'OAS1_0027_MR1',
#  'OAS1_0029_MR1',
#  'OAS1_0037_MR1',
#  'OAS1_0038_MR1',
#  'OAS1_0040_MR1',
#  'OAS1_0043_MR1',
#  'OAS1_0045_MR1',
#  'OAS1_0047_MR1',
#  'OAS1_0049_MR1',
#  'OAS1_0050_MR1',
#  'OAS1_0051_MR1',
#  'OAS1_0054_MR1',
#  'OAS1_0055_MR1',
#  'OAS1_0057_MR1',
#  'OAS1_0059_MR1',
#  'OAS1_0061_MR1',
#  'OAS1_0063_MR1',
#  'OAS1_0076_MR1',
#  'OAS1_0077_MR1',
#  'OAS1_0079_MR1',
#  'OAS1_0080_MR1',
#  'OAS1_0081_MR1',
#  'OAS1_0087_MR1',
#  'OAS1_0088_MR1',
#  'OAS1_0090_MR1',
#  'OAS1_0091_MR1',
#  'OAS1_0092_MR1',
#  'OAS1_0095_MR1',
#  'OAS1_0097_MR1',
#  'OAS1_0099_MR1',
#  'OAS1_0101_MR1',
#  'OAS1_0102_MR1',
#  'OAS1_0103_MR1',
#  'OAS1_0104_MR1',
#  'OAS1_0105_MR1',
#  'OAS1_0107_MR1',
#  'OAS1_0108_MR1',
#  'OAS1_0111_MR1',
#  'OAS1_0117_MR1',
#  'OAS1_0119_MR1',
#  'OAS1_0121_MR1',
# ...

# %%
import shutil
for i in patients_to_remove:
    dir_to_remove=f"OAS1_RAW/{i}"
    shutil.rmtree(dir_to_remove)
